# %%
import pandas as pd

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/My Drive/matches3.csv'

# %%
df = pd.read_csv(file_path, index_col=[0])

# %%
df.head()
# Out:
#           Date   Time       Comp           Round  Day    Venue Result     GF  \
# 21  11/22/2022  13:00  World Cup     Group stage  Tue  Neutral      L      1
# 22  11/26/2022  22:00  World Cup     Group stage  Sat  Neutral      W      2
# 23  11/30/2022  22:00  World Cup     Group stage  Wed  Neutral      W      2
# 24   12/3/2022  22:00  World Cup     Round of 16  Sat  Neutral      W      2
# 25   12/9/2022  22:00  World Cup  Quarter-finals  Fri  Neutral      D  2 (4)
#
#        GA      Opponent  ...  Match Report  \
# 21      2  Saudi Arabia  ...  Match Report
# 22      0        Mexico  ...  Match Report
# 23      0        Poland  ...  Match Report
# 24      1     Australia  ...  Match Report
# 25  2 (3)   Netherlands  ...  Match Report
#
#                                                 Notes  Sh  SoT  Dist FK PK  \
# 21                                                NaN  14    5  16.4  1  1
# 22                                                NaN   5    2  21.1  1  0
# 23                                                NaN  22   10  16.8  0  0
# 24                                                NaN  14    5  16.9  0  0
# 25  Argentina won on penalty kicks following extra...  13    4  21.9  1  1
#
#    PKatt Season        Team
# 21     1   2022  Argentina
# 22     0   2022  Argentina
# 23     1   2022  Argentina
# 24     0   2022  Argentina
# 25     1   2022  Argentina
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (256, 27)

# %%
df["Team"].value_counts()
# Out:
# Team
# Croatia            14
# France             14
# England            12
# Argentina          11
# Belgium            10
# Morocco            10
# Brazil             10
# Portugal            9
# Uruguay             8
# Spain               8
# Switzerland         8
# Japan               8
# Australia           7
# Senegal             7
# Denmark             7
# Poland              7
# Korea Republic      7
# Mexico              7
# Costa Rica          6
# IR Iran             6
# Saudi Arabia        6
# Serbia              6
# Tunisia             6
# Germany             6
# Netherlands         5
# Sweden              5
# Russia              5
# Colombia            4
# United States       4
# Ghana               3
# Egypt               3
# Iceland             3
# Nigeria             3
# Peru                3
# Qatar               3
# Cameroon            3
# Canada              3
# Wales               3
# Ecuador             3
# Panama              3
# Name: count, dtype: int64

# %%
df["Round"].value_counts()
# Out:
# Round
# Group stage          192
# Round of 16           32
# Quarter-finals        16
# Semi-finals            8
# Final                  4
# Third-place match      4
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# Date             object
# Time             object
# Comp             object
# Round            object
# Day              object
# Venue            object
# Result           object
# GF               object
# GA               object
# Opponent         object
# xG              float64
# xGA             float64
# Poss              int64
# Attendance        int64
# Captain          object
# Formation        object
# Referee          object
# Match Report     object
# Notes            object
# Sh                int64
# SoT               int64
# Dist            float64
# FK                int64
# PK                int64
# PKatt             int64
# Season            int64
# Team             object
# dtype: object

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.dtypes
# Out:
# Date            datetime64[ns]
# Time                    object
# Comp                    object
# Round                   object
# Day                     object
# Venue                   object
# Result                  object
# GF                      object
# GA                      object
# Opponent                object
# xG                     float64
# xGA                    float64
# Poss                     int64
# Attendance               int64
# Captain                 object
# Formation               object
# Referee                 object
# Match Report            object
# Notes                   object
# Sh                       int64
# SoT                      int64
# Dist                   float64
# FK                       int64
# PK                       int64
# PKatt                    int64
# Season                   int64
# Team                    object
# dtype: object

# %%
df["venue_code"] = df["Venue"].astype("category").cat.codes

# %%
df["opp_code"] = df["Opponent"].astype("category").cat.codes

# %%
df["hour"] = df["Time"]. str.replace(":.+", "", regex=True).astype("int")

# %%
df["day_code"] = df["Date"].dt.dayofweek

# %%
df["target"] = (df["Result"] == "W").astype("int")

# %%
df
# Out:
#          Date   Time       Comp           Round  Day    Venue Result     GF  \
# 21 2022-11-22  13:00  World Cup     Group stage  Tue  Neutral      L      1
# 22 2022-11-26  22:00  World Cup     Group stage  Sat  Neutral      W      2
# 23 2022-11-30  22:00  World Cup     Group stage  Wed  Neutral      W      2
# 24 2022-12-03  22:00  World Cup     Round of 16  Sat  Neutral      W      2
# 25 2022-12-09  22:00  World Cup  Quarter-finals  Fri  Neutral      D  2 (4)
# ..        ...    ...        ...             ...  ...      ...    ...    ...
# 14 2018-06-19  21:00  World Cup     Group stage  Tue  Neutral      L      1
# 15 2018-06-25  17:00  World Cup     Group stage  Mon  Neutral      L      1
# 21 2018-06-18  18:00  World Cup     Group stage  Mon  Neutral      L      0
# 22 2018-06-24  15:00  World Cup     Group stage  Sun  Neutral      L      1
# 23 2018-06-28  21:00  World Cup     Group stage  Thu  Neutral      L      1
#
#        GA      Opponent  ...  FK  PK  PKatt  Season        Team venue_code  \
# 21      2  Saudi Arabia  ...   1   1      1    2022  Argentina           0
# 22      0        Mexico  ...   1   0      0    2022  Argentina           0
# 23      0        Poland  ...   0   0      1    2022  Argentina           0
# 24      1     Australia  ...   0   0      0    2022  Argentina           0
# 25  2 (3)   Netherlands  ...   1   1      1    2022  Argentina           0
# ..    ...           ...  ...  ..  ..    ...     ...         ...        ...
# 14      3        Russia  ...   0   1      1    2018      Egypt           0
# 15      2  Saudi Arabia  ...   0   0      0    2018      Egypt           0
# 21      3       Belgium  ...   1   0      0    2018     Panama           0
# 22      6       England  ...   0   0      0    2018     Panama           0
# 23      2       Tunisia  ...   1   0      0    2018     Panama           0
#
#    opp_code hour day_code  target
# 21       31   13        1       0
# 22       21   22        5       1
# 23       27   22        2       1
# 24        3   22        5       1
# 25       23   22        4       0
# ..      ...  ...      ...     ...
# 14       30   21        1       0
# 15       31   17        0       0
# 21        4   18        0       0
# 22        0   15        6       0
# 23       37   21        3       0
#
# [256 rows x 32 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = df[df["Date"] < '2022-01-01']

# %%
test = df[df["Date"] > '2022-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds =  rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.578125

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction   0   1
# actual
# 0           62  17
# 1           37  12

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.41379310344827586

# %%
grouped_matches = df.groupby("Team")

# %%
group = grouped_matches.get_group("France ").sort_values("Date")

# %%
def rolling_averages(group, cols, new_cols):
  group = group.sort_values("Date")
  # Convert columns to numeric, coercing errors to NaN
  for col in cols:
    group[col] = pd.to_numeric(group[col], errors='coerce')
  rolling_stats = group[cols].rolling(3, closed='left').mean()
  group[new_cols] = rolling_stats
  group = group.dropna(subset=new_cols)
  return group

# %%
cols = ["GF", "GA", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['GF_rolling',
#  'GA_rolling',
#  'Sh_rolling',
#  'SoT_rolling',
#  'Dist_rolling',
#  'FK_rolling',
#  'PK_rolling',
#  'PKatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          Date   Time       Comp           Round  Day    Venue Result   GF  \
# 18 2018-06-30  17:00  World Cup     Round of 16  Sat  Neutral      W  4.0
# 19 2018-07-06  17:00  World Cup  Quarter-finals  Fri  Neutral      W  2.0
# 20 2018-07-10  21:00  World Cup     Semi-finals  Tue  Neutral      W  1.0
# 21 2018-07-15  18:00  World Cup           Final  Sun  Neutral      W  4.0
# 10 2022-11-22  22:00  World Cup     Group stage  Tue  Neutral      W  4.0
# 11 2022-11-26  19:00  World Cup     Group stage  Sat  Neutral      W  2.0
# 12 2022-11-30  18:00  World Cup     Group stage  Wed  Neutral      L  0.0
# 13 2022-12-04  18:00  World Cup     Round of 16  Sun  Neutral      W  3.0
# 14 2022-12-10  22:00  World Cup  Quarter-finals  Sat  Neutral      W  2.0
# 15 2022-12-14  22:00  World Cup     Semi-finals  Wed  Neutral      W  2.0
# 16 2022-12-18  18:00  World Cup           Final  Sun  Neutral      D  NaN
#
#      GA   Opponent  ...  day_code  target  GF_rolling  GA_rolling Sh_rolling  \
# 18  3.0  Argentina  ...         5       1    1.000000    0.333333  11.333333
# 19  0.0    Uruguay  ...         4       1    1.666667    1.000000  10.333333
# 20  0.0    Belgium  ...         1       1    2.000000    1.000000  10.000000
# 21  2.0    Croatia  ...         6       1    2.333333    1.000000  12.666667
# 10  1.0  Australia  ...         1       1    2.333333    0.666667  12.000000
# 11  1.0    Denmark  ...         5       1    3.000000    1.000000  16.000000
# 12  1.0    Tunisia  ...         2       0    3.333333    1.333333  16.666667
# 13  1.0     Poland  ...         6       1    2.000000    1.000000  18.000000
# 14  1.0    England  ...         5       1    1.666667    1.000000  15.666667
# 15  0.0    Morocco  ...         2       1    1.666667    1.000000  11.333333
# 16  NaN  Argentina  ...         6       0    2.333333    0.666667  12.666667
#
#    SoT_rolling Dist_rolling FK_rolling PK_rolling  PKatt_rolling
# 18    3.666667    20.800000   0.666667   0.333333       0.333333
# 19    3.333333    18.800000   0.666667   0.333333       0.333333
# 20    2.666667    21.500000   1.000000   0.333333       0.333333
# 21    3.333333    19.933333   1.333333   0.333333       0.333333
# 10    4.000000    22.600000   0.666667   0.333333       0.333333
# 11    5.333333    19.266667   0.333333   0.333333       0.333333
# 12    5.666667    17.833333   0.000000   0.333333       0.333333
# 13    5.000000    15.466667   0.333333   0.000000       0.000000
# 14    5.666667    16.866667   0.666667   0.000000       0.000000
# 15    5.333333    17.733333   0.666667   0.000000       0.000000
# 16    5.000000    15.766667   0.333333   0.000000       0.000000
#
# [11 rows x 40 columns]

# %%
matches_rolling = df.groupby("Team").apply(lambda x: rolling_averages(x, cols,new_cols))

# %%
matches_rolling
# Out:
#                     Date   Time       Comp           Round  Day    Venue  \
# Team
# Argentina  24 2018-06-30  17:00  World Cup     Round of 16  Sat  Neutral
#            21 2022-11-22  13:00  World Cup     Group stage  Tue  Neutral
#            22 2022-11-26  22:00  World Cup     Group stage  Sat  Neutral
#            23 2022-11-30  22:00  World Cup     Group stage  Wed  Neutral
#            24 2022-12-03  22:00  World Cup     Round of 16  Sat  Neutral
# ...                  ...    ...        ...             ...  ...      ...
# Uruguay    22 2018-06-30  21:00  World Cup     Round of 16  Sat  Neutral
#            23 2018-07-06  17:00  World Cup  Quarter-finals  Fri  Neutral
#            21 2022-11-24  16:00  World Cup     Group stage  Thu  Neutral
#            22 2022-11-28  22:00  World Cup     Group stage  Mon  Neutral
#            23 2022-12-02  18:00  World Cup     Group stage  Fri  Neutral
#
#               Result   GF   GA        Opponent  ...  day_code  target  \
# Team                                            ...
# Argentina  24      L  3.0  4.0          France  ...         5       0
#            21      L  1.0  2.0    Saudi Arabia  ...         1       0
#            22      W  2.0  0.0          Mexico  ...         5       1
#            23      W  2.0  0.0          Poland  ...         2       1
#            24      W  2.0  1.0       Australia  ...         5       1
# ...              ...  ...  ...             ...  ...       ...     ...
# Uruguay    22      W  2.0  1.0        Portugal  ...         5       1
#            23      L  0.0  2.0          France  ...         4       0
#            21      D  0.0  0.0  Korea Republic  ...         3       0
#            22      L  0.0  2.0        Portugal  ...         0       0
#            23      W  2.0  0.0           Ghana  ...         4       1
#
#                GF_rolling  GA_rolling Sh_rolling SoT_rolling Dist_rolling  \
# Team
# Argentina  24    1.000000    1.666667  14.666667    4.333333    17.533333
#            21    1.666667    2.666667   9.333333    3.666667    16.666667
#            22    2.000000    2.333333  10.666667    4.333333    17.066667
#            23    2.000000    2.000000   9.666667    3.666667    19.066667
#            24    1.666667    0.666667  13.666667    5.666667    18.100000
# ...                   ...         ...        ...         ...          ...
# Uruguay    22    1.666667    0.000000  14.666667    4.666667    18.533333
#            23    2.000000    0.333333  11.333333    4.000000    18.700000
#            21    1.666667    1.000000  10.666667    4.333333    20.600000
#            22    0.666667    1.000000   8.666667    2.666667    19.633333
#            23    0.000000    1.333333  10.666667    2.666667    19.266667
#
#               FK_rolling PK_rolling  PKatt_rolling
# Team
# Argentina  24   1.333333   0.000000       0.333333
#            21   0.666667   0.000000       0.000000
#            22   1.000000   0.333333       0.333333
#            23   1.000000   0.333333       0.333333
#            24   0.666667   0.333333       0.666667
# ...                  ...        ...            ...
# Uruguay    22   1.666667   0.000000       0.000000
#            23   1.333333   0.000000       0.000000
#            21   1.000000   0.000000       0.000000
#            22   0.333333   0.000000       0.000000
#            23   0.000000   0.000000       0.000000
#
# [112 rows x 40 columns]

# %%
matches_rolling = matches_rolling.droplevel("Team")

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#           Date   Time       Comp           Round  Day    Venue Result   GF  \
# 0   2018-06-30  17:00  World Cup     Round of 16  Sat  Neutral      L  3.0
# 1   2022-11-22  13:00  World Cup     Group stage  Tue  Neutral      L  1.0
# 2   2022-11-26  22:00  World Cup     Group stage  Sat  Neutral      W  2.0
# 3   2022-11-30  22:00  World Cup     Group stage  Wed  Neutral      W  2.0
# 4   2022-12-03  22:00  World Cup     Round of 16  Sat  Neutral      W  2.0
# ..         ...    ...        ...             ...  ...      ...    ...  ...
# 107 2018-06-30  21:00  World Cup     Round of 16  Sat  Neutral      W  2.0
# 108 2018-07-06  17:00  World Cup  Quarter-finals  Fri  Neutral      L  0.0
# 109 2022-11-24  16:00  World Cup     Group stage  Thu  Neutral      D  0.0
# 110 2022-11-28  22:00  World Cup     Group stage  Mon  Neutral      L  0.0
# 111 2022-12-02  18:00  World Cup     Group stage  Fri  Neutral      W  2.0
#
#       GA        Opponent  ...  day_code  target  GF_rolling  GA_rolling  \
# 0    4.0          France  ...         5       0    1.000000    1.666667
# 1    2.0    Saudi Arabia  ...         1       0    1.666667    2.666667
# 2    0.0          Mexico  ...         5       1    2.000000    2.333333
# 3    0.0          Poland  ...         2       1    2.000000    2.000000
# 4    1.0       Australia  ...         5       1    1.666667    0.666667
# ..   ...             ...  ...       ...     ...         ...         ...
# 107  1.0        Portugal  ...         5       1    1.666667    0.000000
# 108  2.0          France  ...         4       0    2.000000    0.333333
# 109  0.0  Korea Republic  ...         3       0    1.666667    1.000000
# 110  2.0        Portugal  ...         0       0    0.666667    1.000000
# 111  0.0           Ghana  ...         4       1    0.000000    1.333333
#
#     Sh_rolling SoT_rolling Dist_rolling FK_rolling PK_rolling  PKatt_rolling
# 0    14.666667    4.333333    17.533333   1.333333   0.000000       0.333333
# 1     9.333333    3.666667    16.666667   0.666667   0.000000       0.000000
# 2    10.666667    4.333333    17.066667   1.000000   0.333333       0.333333
# 3     9.666667    3.666667    19.066667   1.000000   0.333333       0.333333
# 4    13.666667    5.666667    18.100000   0.666667   0.333333       0.666667
# ..         ...         ...          ...        ...        ...            ...
# 107  14.666667    4.666667    18.533333   1.666667   0.000000       0.000000
# 108  11.333333    4.000000    18.700000   1.333333   0.000000       0.000000
# 109  10.666667    4.333333    20.600000   1.000000   0.000000       0.000000
# 110   8.666667    2.666667    19.633333   0.333333   0.000000       0.000000
# 111  10.666667    2.666667    19.266667   0.000000   0.000000       0.000000
#
# [112 rows x 40 columns]

# %%
def make_predictions(data, predictions):
  train = data[data["Date"] < '2022-01-01']
  test = data[data["Date"] > '2022-01-01']
  rf.fit(train[predictors], train["target"])
  preds = rf.predict(test[predictors])
  combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
  precision = precision_score(test["target"], preds)
  return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.3181818181818182

# %%
combined
# Out:
#      actual  predicted
# 1         0          0
# 2         1          0
# 3         1          0
# 4         1          0
# 5         0          1
# ..      ...        ...
# 105       1          0
# 106       0          1
# 109       0          1
# 110       0          0
# 111       1          0
#
# [87 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["Date", "Team", "Opponent", "Result"]], left_index=True, right_index=True)

# %%
combined.head(10)
# Out:
#     actual  predicted       Date        Team      Opponent Result
# 1        0          0 2022-11-22  Argentina   Saudi Arabia      L
# 2        1          0 2022-11-26  Argentina         Mexico      W
# 3        1          0 2022-11-30  Argentina         Poland      W
# 4        1          0 2022-12-03  Argentina      Australia      W
# 5        0          1 2022-12-09  Argentina    Netherlands      D
# 6        0          0 2022-11-22  Australia         France      L
# 7        1          1 2022-11-26  Australia        Tunisia      W
# 8        1          0 2022-11-30  Australia        Denmark      W
# 9        0          0 2022-12-03  Australia      Argentina      L
# 14       1          0 2022-11-23    Belgium         Canada      W

# %%
combined
# Out:
#      actual  predicted       Date            Team        Opponent Result  \
# 1         0          0 2022-11-22      Argentina     Saudi Arabia      L
# 2         1          0 2022-11-26      Argentina           Mexico      W
# 3         1          0 2022-11-30      Argentina           Poland      W
# 4         1          0 2022-12-03      Argentina        Australia      W
# 5         0          1 2022-12-09      Argentina      Netherlands      D
# ..      ...        ...        ...             ...             ...    ...
# 105       1          0 2022-11-30        Tunisia           France      W
# 106       0          1 2022-12-03  United States      Netherlands      L
# 109       0          1 2022-11-24        Uruguay   Korea Republic      D
# 110       0          0 2022-11-28        Uruguay         Portugal      L
# 111       1          0 2022-12-02        Uruguay            Ghana      W
#
#            new_team
# 1        Argentina
# 2        Argentina
# 3        Argentina
# 4        Argentina
# 5        Argentina
# ..              ...
# 105        Tunisia
# 106  United States
# 109        Uruguay
# 110        Uruguay
# 111        Uruguay
#
# [87 rows x 7 columns]

# %%
merged = pd.merge(combined, combined, on='Team')

# %%
merged
# Out:
#      actual_x  predicted_x     Date_x        Team    Opponent_x Result_x  \
# 0           0            0 2022-11-22  Argentina   Saudi Arabia        L
# 1           0            0 2022-11-22  Argentina   Saudi Arabia        L
# 2           0            0 2022-11-22  Argentina   Saudi Arabia        L
# 3           0            0 2022-11-22  Argentina   Saudi Arabia        L
# 4           0            0 2022-11-22  Argentina   Saudi Arabia        L
# ..        ...          ...        ...         ...           ...      ...
# 344         0            0 2022-11-28    Uruguay       Portugal        L
# 345         0            0 2022-11-28    Uruguay       Portugal        L
# 346         1            0 2022-12-02    Uruguay          Ghana        W
# 347         1            0 2022-12-02    Uruguay          Ghana        W
# 348         1            0 2022-12-02    Uruguay          Ghana        W
#
#      new_team_x  actual_y  predicted_y     Date_y      Opponent_y Result_y  \
# 0    Argentina          0            0 2022-11-22    Saudi Arabia        L
# 1    Argentina          1            0 2022-11-26          Mexico        W
# 2    Argentina          1            0 2022-11-30          Poland        W
# 3    Argentina          1            0 2022-12-03       Australia        W
# 4    Argentina          0            1 2022-12-09     Netherlands        D
# ..          ...       ...          ...        ...             ...      ...
# 344    Uruguay          0            0 2022-11-28        Portugal        L
# 345    Uruguay          1            0 2022-12-02           Ghana        W
# 346    Uruguay          0            1 2022-11-24  Korea Republic        D
# 347    Uruguay          0            0 2022-11-28        Portugal        L
# 348    Uruguay          1            0 2022-12-02           Ghana        W
#
#      new_team_y
# 0    Argentina
# 1    Argentina
# 2    Argentina
# 3    Argentina
# 4    Argentina
# ..          ...
# 344    Uruguay
# 345    Uruguay
# 346    Uruguay
# 347    Uruguay
# 348    Uruguay
#
# [349 rows x 13 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 0    35
# 1    18
# Name: count, dtype: int64
